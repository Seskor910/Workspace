# %% [markdown]
# # Menggabung Image

# %% [markdown]
# ## Depression dataset

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Folder paths for each type of data
folders = {
    "Correlation": r"E:\Vscode\Tugas Anime\Workspace\Eksperimen_4\Depression\csv_data_correlation_depression",
    "Theta": r"E:\Vscode\Tugas Anime\Workspace\Eksperimen_4\Depression\csv_data_coherence_depression\theta_band_csv_depression",
    "Delta": r"E:\Vscode\Tugas Anime\Workspace\Eksperimen_4\Depression\csv_data_coherence_depression\delta_band_csv_depression",
    "Alpha": r"E:\Vscode\Tugas Anime\Workspace\Eksperimen_4\Depression\csv_data_coherence_depression\alpha_band_csv_depression",
    "Beta": r"E:\Vscode\Tugas Anime\Workspace\Eksperimen_4\Depression\csv_data_coherence_depression\beta_band_csv_depression",
    "Gamma": r"E:\Vscode\Tugas Anime\Workspace\Eksperimen_4\Depression\csv_data_coherence_depression\gamma_band_csv_depression"
}

# output_dir = r"E:\Vscode\Tugas Anime\Workspace\Eksperimen_4\Depression\combined_csv_depression"
# if not os.path.exists(output_dir):
#     os.makedirs(output_dir)

image_output_dir = r"E:\Vscode\Tugas Anime\Workspace\Eksperimen_4\Depression\combined_image_depression"
if not os.path.exists(image_output_dir):
    os.makedirs(image_output_dir)

# Define a function to process each set of files
def process_files(files_dict):
    matrices = {}
    for key, filepath in files_dict.items():
        # Read CSV file with headers for all data
        matrix = pd.read_csv(filepath, index_col=0).values[:8, :8]
        matrices[key] = matrix

    # Create a large 16x24 matrix to hold all the smaller matrices
    large_matrix = np.zeros((16, 24))
    positions = [(0, 0), (0, 8), (0, 16), (8, 0), (8, 8), (8, 16)]
    keys = ["Correlation", "Theta", "Delta", "Alpha", "Beta", "Gamma"]

    for key, pos in zip(keys, positions):
        large_matrix[pos[0]:pos[0]+8, pos[1]:pos[1]+8] = matrices[key]

    # Save the large matrix to a CSV file
    # save_path = os.path.join(output_dir, f"combined_matrix_{index+1}.csv")
    # pd.DataFrame(large_matrix).to_csv(save_path, index=False, header=False)

    # Plot the large matrix using Seaborn
    plt.figure(figsize=(12, 8))
    sns.heatmap(large_matrix, cmap='viridis', cbar=False, vmin=0, vmax=1)
    # plt.title(f'Combined EEG Correlation and Coherence Matrix {index+1}')
    
    # Save the plot
    image_save_path = os.path.join(image_output_dir, f"combined_matrix_{index+1}.png")
    plt.savefig(image_save_path)
    plt.close()  # Close the figure to free up memory

# Iterate through the files in the folders
file_lists = {key: sorted([os.path.join(path, file) for file in os.listdir(path)]) for key, path in folders.items()}

# Assuming that each folder has the same number of files
for index in range(len(file_lists["Correlation"])):
    files_dict = {key: file_lists[key][index] for key in file_lists}
    process_files(files_dict)


# import os
# import numpy as np
# import pandas as pd

# # Folder paths for each type of data
# folders = {
#     "Correlation": r"E:\Vscode\Tugas Anime\Workspace\Eksperimen_4\Depression\csv_data_correlation_depression",
#     "Theta": r"E:\Vscode\Tugas Anime\Workspace\Eksperimen_4\Depression\csv_data_coherence_depression\theta_band_csv_depression",
#     "Delta": r"E:\Vscode\Tugas Anime\Workspace\Eksperimen_4\Depression\csv_data_coherence_depression\delta_band_csv_depression",
#     "Alpha": r"E:\Vscode\Tugas Anime\Workspace\Eksperimen_4\Depression\csv_data_coherence_depression\alpha_band_csv_depression",
#     "Beta": r"E:\Vscode\Tugas Anime\Workspace\Eksperimen_4\Depression\csv_data_coherence_depression\beta_band_csv_depression",
#     "Gamma": r"E:\Vscode\Tugas Anime\Workspace\Eksperimen_4\Depression\csv_data_coherence_depression\gamma_band_csv_depression"
# }

# output_dir = r"E:\Vscode\Tugas Anime\Workspace\Eksperimen_4\Depression\combined_csv_depression"
# if not os.path.exists(output_dir):
#     os.makedirs(output_dir)

# # Define a function to process each set of files
# def process_files(files_dict, index):
#     matrices = {}
#     for key, filepath in files_dict.items():
#         # Read CSV file with headers for all data
#         matrix = pd.read_csv(filepath, index_col=0).values[:8, :8]
#         matrices[key] = matrix

#     # Create a large 16x24 matrix to hold all the smaller matrices
#     large_matrix = np.zeros((16, 24))
#     positions = [(0, 0), (0, 8), (0, 16), (8, 0), (8, 8), (8, 16)]
#     keys = ["Correlation", "Theta", "Delta", "Alpha", "Beta", "Gamma"]

#     for key, pos in zip(keys, positions):
#         large_matrix[pos[0]:pos[0]+8, pos[1]:pos[1]+8] = matrices[key]

#     # Save the large matrix to a CSV file
#     save_path = os.path.join(output_dir, f"combined_matrix_{index+1}.csv")
#     pd.DataFrame(large_matrix).to_csv(save_path, index=False, header=False)

# # Iterate through the files in the folders
# file_lists = {key: sorted([os.path.join(path, file) for file in os.listdir(path)]) for key, path in folders.items()}

# # Assuming that each folder has the same number of files
# for index in range(len(file_lists["Correlation"])):
#     files_dict = {key: file_lists[key][index] for key in file_lists}
#     process_files(files_dict, index)

# %% [markdown]
# ## Healthy dataset

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Folder paths for each type of data
folders = {
    "Correlation": r"E:\Vscode\Tugas Anime\Workspace\Eksperimen_4\Healthy\csv_data_correlation_healthy",
    "Theta": r"E:\Vscode\Tugas Anime\Workspace\Eksperimen_4\Healthy\csv_data_coherence_Healthy\theta_band_csv_healthy",
    "Delta": r"E:\Vscode\Tugas Anime\Workspace\Eksperimen_4\Healthy\csv_data_coherence_Healthy\delta_band_csv_healthy",
    "Alpha": r"E:\Vscode\Tugas Anime\Workspace\Eksperimen_4\Healthy\csv_data_coherence_Healthy\alpha_band_csv_healthy",
    "Beta": r"E:\Vscode\Tugas Anime\Workspace\Eksperimen_4\Healthy\csv_data_coherence_Healthy\beta_band_csv_healthy",
    "Gamma": r"E:\Vscode\Tugas Anime\Workspace\Eksperimen_4\Healthy\csv_data_coherence_Healthy\gamma_band_csv_healthy"
}

output_dir = r"E:\Vscode\Tugas Anime\Workspace\Eksperimen_4\Healthy\combined_image_healthy"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Define a function to process each set of files
def process_files(files_dict):
    matrices = {}
    for key, filepath in files_dict.items():
        matrix = pd.read_csv(filepath, index_col=0).values[:8, :8]
        matrices[key] = matrix

    # Create a large 16x24 matrix to hold all the smaller matrices
    large_matrix = np.zeros((16, 24))
    positions = [(0, 0), (0, 8), (0, 16), (8, 0), (8, 8), (8, 16)]
    keys = ["Correlation", "Theta", "Delta", "Alpha", "Beta", "Gamma"]

    for key, pos in zip(keys, positions):
        large_matrix[pos[0]:pos[0]+8, pos[1]:pos[1]+8] = matrices[key]

    # Plotting the large matrix
    plt.figure(figsize=(12, 8))
    # plt.imshow(large_matrix, cmap='viridis', aspect='auto')
    # plt.colorbar()
    # plt.title('Combined EEG Correlation and Coherence Matrix')
    sns.heatmap(large_matrix, cmap='viridis', cbar=False, vmin=0, vmax=1)
    
    # Save the plot
    save_path = os.path.join(output_dir, f"combined_matrix_{index+1}.png")
    plt.savefig(save_path)
    plt.close()  # Close the figure to free up memory

# Iterate through the files in the folders
file_lists = {key: sorted([os.path.join(path, file) for file in os.listdir(path)]) for key, path in folders.items()}

# Assuming that each folder has the same number of files
for index in range(len(file_lists["Correlation"])):
    files_dict = {key: file_lists[key][index] for key in file_lists}
    process_files(files_dict)
